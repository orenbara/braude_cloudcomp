# %% [markdown]
# <a href="https://colab.research.google.com/github/orenbara/braude_cloudcomp/blob/master/CLoud_Course_ex_4_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Connect Google Drive
mount_path = "/content/drive" # @param {type:"string"}
# Connect to Google Drive
from google.colab import drive
drive.mount(mount_path)
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import json

# Load JSON data from a file
file_path = '/content/drive/MyDrive/Colab Notebooks/Cloud Compute Course Braude/data.json'
with open(file_path, 'r') as f:
    data = json.load(f)

# Check the structure of the loaded JSON data
#print(data)

# Ensure 'records' is in the data
if 'records' in data:
    # Convert JSON data to DataFrame
    df = pd.json_normalize(data, 'records')

    # Use DateTime object instead of string - much more data manipulations are available with DateTime
    df['Time'] = pd.to_datetime(df['Time'])

    # Set 'Time' as the index
    df.set_index('Time', inplace=True)

    # Resample the data by day and count the number of events per day - this is very simular to GROUPBY in SQL
    events_per_day = df.resample('D').size()

    # Display the DataFrame - keys of the json inside the json array "records" are displayed as columns
    print(df)


    # Plot the data
    plt.figure(figsize=(10, 6))
    plt.plot(events_per_day.index, events_per_day.values, color='#8a5082', marker='o')
    plt.grid(True)
    plt.xlabel('Date')
    plt.ylabel('Number of Events')
    plt.title('Number of Events Over Time')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("The records brought from Tirgul 3 must be inside an array called recors")


##### Let the user choose
choose_the_field_you_want = "Document" # @param {type:"string"}
if choose_the_field_you_want in df.columns:
    x = df['Document']
    y = df['Time']
    plt.figure(figsize=(10, 6))
    plt.plot(df['User'], df['Document'], color='#8a5082', marker='o')
    plt.grid(True)
    plt.xlabel('Date')
    plt.ylabel('Number of Events')
    plt.title('Number of Events Over Time')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f"{choose_the_field_you_want} is not one of the columns.")
# Out:
#                                      Document                   Tab  \
# Time
# 2023-01-13 14:12:54      Industry 4.0 Project                   N/A
# 2023-01-13 14:12:53      Industry 4.0 Project  Part Studio 2 Copy 1
# 2023-01-13 13:27:38      Industry 4.0 Project  Part Studio 2 Copy 1
# 2023-01-13 13:27:37      Industry 4.0 Project  Part Studio 2 Copy 1
# 2023-01-13 13:27:37      Industry 4.0 Project  Part Studio 2 Copy 1
# ...                                       ...                   ...
# 2022-11-09 11:42:49  rotation to displacement            Assembly 1
# 2022-11-09 11:42:48  rotation to displacement                   N/A
# 2022-11-09 11:42:43  rotation to displacement            Assembly 1
# 2022-11-09 11:42:42  rotation to displacement            Assembly 1
# 2022-11-09 11:42:41  rotation to displacement                   N/A
#
#                           User  \
# Time
# 2023-01-13 14:12:54  StudentA1
# 2023-01-13 14:12:53  StudentA1
# 2023-01-13 13:27:38  StudentA1
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import json

# Load JSON data from a file
file_path = '/content/drive/MyDrive/Colab Notebooks/Cloud Compute Course Braude/data.json'
with open(file_path, 'r') as f:
    data = json.load(f)

# Check the structure of the loaded JSON data
#print(data)

# Ensure 'records' is in the data
if 'records' in data:
    # Convert JSON data to DataFrame
    df = pd.json_normalize(data, 'records')

    # Use DateTime object instead of string - much more data manipulations are available with DateTime
    df['Time'] = pd.to_datetime(df['Time'])

    # Set 'Time' as the index
    df.set_index('Time', inplace=True)

    # Resample the data by day and count the number of events per day - this is very simular to GROUPBY in SQL
    events_per_day = df.resample('D').size()

    # Display the DataFrame - keys of the json inside the json array "records" are displayed as columns
    print(df)


    # Plot the data
    plt.figure(figsize=(10, 6))
    plt.plot(events_per_day.index, events_per_day.values, color='#8a5082', marker='o')
    plt.grid(True)
    plt.xlabel('Date')
    plt.ylabel('Number of Events')
    plt.title('Number of Events Over Time')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("The records brought from Tirgul 3 must be inside an array called recors")


##### Let the user choose
choose_the_field_you_want = "Document" # @param {type:"string"}
if choose_the_field_you_want in df.columns:
    x = df['Document']
    # Access the index as a Series using df.index
    y = df.index
    plt.figure(figsize=(10, 6))
    # Use the correct column names for plotting
    plt.plot(df.index, df['Document'].fillna(''), color='#8a5082', marker='o')
    plt.grid(True)
    plt.xlabel('User') # Update x-axis label
    plt.ylabel('Document') # Update y-axis label
    plt.title('User vs Document') # Update title
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f"{choose_the_field_you_want} is not one of the columns.")
# Out:
#                                      Document                   Tab  \
# Time
# 2023-01-13 14:12:54      Industry 4.0 Project                   N/A
# 2023-01-13 14:12:53      Industry 4.0 Project  Part Studio 2 Copy 1
# 2023-01-13 13:27:38      Industry 4.0 Project  Part Studio 2 Copy 1
# 2023-01-13 13:27:37      Industry 4.0 Project  Part Studio 2 Copy 1
# 2023-01-13 13:27:37      Industry 4.0 Project  Part Studio 2 Copy 1
# ...                                       ...                   ...
# 2022-11-09 11:42:49  rotation to displacement            Assembly 1
# 2022-11-09 11:42:48  rotation to displacement                   N/A
# 2022-11-09 11:42:43  rotation to displacement            Assembly 1
# 2022-11-09 11:42:42  rotation to displacement            Assembly 1
# 2022-11-09 11:42:41  rotation to displacement                   N/A
#
#                           User  \
# Time
# 2023-01-13 14:12:54  StudentA1
# 2023-01-13 14:12:53  StudentA1
# 2023-01-13 13:27:38  StudentA1
# ...
